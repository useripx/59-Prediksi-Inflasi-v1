# %% [markdown]
# # Prediksi Inflasi Bulanan
# Notebook ini berisi eksperimen dengan 7 algoritma (RF, XGBoost, SVR, LinReg, Prophet, SARIMA, LSTM).

# %%
import pandas as pd
df = pd.read_excel('asset/Data Inflasi.xlsx', skiprows=4)
df.head()
